# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import RMSprop
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# %%
df_lstm_pred = pd.read_csv("volatility_predictions.csv", index_col=0, parse_dates=True)
df_lstm_pred = df_lstm_pred.sort_index()

# %%
sequence_length = 90  # Increase to 90 days instead of 60

# %%
# Normalize the 'Rolling_Volatility' for LSTM training
scaler = MinMaxScaler()
df_lstm_pred['Scaled_Volatility'] = scaler.fit_transform(df_lstm_pred[['Rolling_Volatility']])

# %%
def create_sequences(data, seq_length):
    X, y = [], []
    for i in range(len(data) - seq_length):
        X.append(data[i : i + seq_length])
        y.append(data[i + seq_length])
    return np.array(X), np.array(y)

X, y = create_sequences(df_lstm_pred['Scaled_Volatility'].values, sequence_length)

# Split data into train & test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# Reshape for LSTM input
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test  = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# %%
# === Build LSTM Model ===
model = Sequential([
    LSTM(128, return_sequences=True, input_shape=(sequence_length, 1)),
    Dropout(0.3),
    LSTM(128, return_sequences=True),
    BatchNormalization(),
    Dropout(0.3),
    LSTM(128, return_sequences=False),
    BatchNormalization(),
    Dropout(0.3),
    Dense(64, activation="relu"),
    Dense(1)
])


model.compile(optimizer='adam', loss='mean_squared_error')

# %%
history = model.fit(X_train, y_train, epochs=150, batch_size=16, validation_data=(X_test, y_test), verbose=1)
# Out:
# Epoch 1/100
# 63/63 [==============================] - 11s 113ms/step - loss: 0.5895 - val_loss: 0.0229
# Epoch 2/100
# 63/63 [==============================] - 6s 103ms/step - loss: 0.2723 - val_loss: 0.0341
# Epoch 3/100
# 63/63 [==============================] - 6s 98ms/step - loss: 0.1652 - val_loss: 0.0198
# Epoch 4/100
# 63/63 [==============================] - 6s 98ms/step - loss: 0.1045 - val_loss: 0.0070
# Epoch 5/100
# 63/63 [==============================] - 6s 98ms/step - loss: 0.0844 - val_loss: 0.0061
# Epoch 6/100
# 63/63 [==============================] - 6s 98ms/step - loss: 0.0559 - val_loss: 0.0051
# Epoch 7/100
# 63/63 [==============================] - 6s 96ms/step - loss: 0.0515 - val_loss: 0.0023
# Epoch 8/100
# 63/63 [==============================] - 6s 98ms/step - loss: 0.0364 - val_loss: 0.0086
# Epoch 9/100
# 63/63 [==============================] - 6s 98ms/step - loss: 0.0316 - val_loss: 0.0144
# Epoch 10/100
# 63/63 [==============================] - 6s 97ms/step - loss: 0.0296 - val_loss: 0.0043
# Epoch 11/100
# 63/63 [==============================] - 6s 97ms/step - loss: 0.0282 - val_loss: 0.0488
# Epoch 12/100
# 63/63 [==============================] - 6s 96ms/step - loss: 0.0200 - val_loss: 0.0098
# Epoch 13/100
# 63/63 [==============================] - 6s 97ms/step - loss: 0.0358 - val_loss: 0.0411
# Epoch 14/100
# 63/63 [==============================] - 6s 97ms/step - loss: 0.0195 - val_loss: 0.0043
# Epoch 15/100
# 63/63 [==============================] - 6s 96ms/step - loss: 0.0133 - val_loss: 0.1016
# Epoch 16/100
# 63/63 [==============================] - 6s 98ms/step - loss: 0.0056 - val_loss: 0.2530
# Epoch 17/100
# 63/63 [==============================] - 6s 97ms/step - loss: 0.0035 - val_loss: 0.3724
# Epoch 18/100
# 63/63 [==============================] - 6s 98ms/step - loss: 0.0030 - val_loss: 0.1941
# Epoch 19/100
# 63/63 [==============================] - 6s 97ms/step - loss: 0.0031 - val_loss: 0.2332
# Epoch 20/100
# 63/63 [==============================] - 6s 98ms/step - loss: 0.0024 - val_loss: 0.2359
# Epoch 21/100
# 63/63 [==============================] - 6s 96ms/step - loss: 0.0024 - val_loss: 0.1515
# Epoch 22/100
# 63/63 [==============================] - 6s 98ms/step - loss: 0.0021 - val_loss: 0.0010
# Epoch 23/100
# 63/63 [==============================] - 6s 97ms/step - loss: 0.0022 - val_loss: 0.0191
# Epoch 24/100
# 63/63 [==============================] - 6s 98ms/step - loss: 0.0025 - val_loss: 0.0193
# Epoch 25/100
# 63/63 [==============================] - 6s 96ms/step - loss: 0.0023 - val_loss: 0.0161
# Epoch 26/100
# 63/63 [==============================] - 6s 96ms/step - loss: 0.0019 - val_loss: 6.5766e-04
# Epoch 27/100
# 63/63 [==============================] - 6s 98ms/step - loss: 0.0015 - val_loss: 0.0050
# Epoch 28/100
# 63/63 [==============================] - 6s 97ms/step - loss: 0.0019 - val_loss: 0.0012
# Epoch 29/100
# 63/63 [==============================] - 6s 99ms/step - loss: 0.0017 - val_loss: 0.0069
# Epoch 30/100
# 63/63 [==============================] - 6s 97ms/step - loss: 0.0016 - val_loss: 8.7043e-04
# Epoch 31/100
# 63/63 [==============================] - 6s 97ms/step - loss: 0.0015 - val_loss: 0.0111
# Epoch 32/100
# 63/63 [==============================] - 6s 98ms/step - loss: 0.0014 - val_loss: 6.8804e-04
# Epoch 33/100
# 63/63 [==============================] - 6s 98ms/step - loss: 0.0016 - val_loss: 0.0326
# Epoch 34/100
# 63/63 [==============================] - 6s 99ms/step - loss: 0.0015 - val_loss: 5.3907e-04
# Epoch 35/100
# 63/63 [==============================] - 6s 97ms/step - loss: 0.0013 - val_loss: 3.7965e-04
# Epoch 36/100
# 63/63 [==============================] - 6s 98ms/step - loss: 0.0017 - val_loss: 0.0021
# Epoch 37/100
# 63/63 [==============================] - 6s 97ms/step - loss: 0.0017 - val_loss: 0.0061
# Epoch 38/100
# 63/63 [==============================] - 6s 98ms/step - loss: 0.0013 - val_loss: 0.0329
# Epoch 39/100
# 63/63 [==============================] - 6s 99ms/step - loss: 0.0015 - val_loss: 0.0067
# Epoch 40/100
# 63/63 [==============================] - 6s 98ms/step - loss: 0.0014 - val_loss: 0.0050
# Epoch 41/100
# 63/63 [==============================] - 6s 98ms/step - loss: 0.0013 - val_loss: 0.0196
# Epoch 42/100
# 63/63 [==============================] - 6s 98ms/step - loss: 0.0014 - val_loss: 0.0043
# Epoch 43/100
# 63/63 [==============================] - 6s 100ms/step - loss: 0.0014 - val_loss: 0.0156
# Epoch 44/100
# 63/63 [==============================] - 6s 99ms/step - loss: 0.0017 - val_loss: 0.0084
# Epoch 45/100
# 63/63 [==============================] - 6s 98ms/step - loss: 0.0011 - val_loss: 0.0036
# Epoch 46/100
# 63/63 [==============================] - 6s 99ms/step - loss: 0.0014 - val_loss: 1.6852e-04
# Epoch 47/100
# 63/63 [==============================] - 6s 99ms/step - loss: 0.0014 - val_loss: 0.0057
# Epoch 48/100
# 63/63 [==============================] - 6s 99ms/step - loss: 0.0011 - val_loss: 0.0091
# Epoch 49/100
# 63/63 [==============================] - 6s 100ms/step - loss: 0.0017 - val_loss: 0.0173
# Epoch 50/100
# 63/63 [==============================] - 6s 99ms/step - loss: 0.0013 - val_loss: 0.0130
# Epoch 51/100
# 63/63 [==============================] - 6s 99ms/step - loss: 0.0014 - val_loss: 0.0099
# Epoch 52/100
# 63/63 [==============================] - 6s 99ms/step - loss: 9.5602e-04 - val_loss: 3.4396e-04
# Epoch 53/100
# 63/63 [==============================] - 6s 99ms/step - loss: 0.0015 - val_loss: 0.0063
# Epoch 54/100
# 63/63 [==============================] - 6s 99ms/step - loss: 0.0011 - val_loss: 0.0013
# Epoch 55/100
# 63/63 [==============================] - 6s 101ms/step - loss: 0.0016 - val_loss: 0.0049
# Epoch 56/100
# 63/63 [==============================] - 6s 99ms/step - loss: 0.0012 - val_loss: 0.0029
# Epoch 57/100
# 63/63 [==============================] - 6s 98ms/step - loss: 0.0013 - val_loss: 0.0120
# Epoch 58/100
# 63/63 [==============================] - 6s 98ms/step - loss: 0.0014 - val_loss: 0.0184
# Epoch 59/100
# 63/63 [==============================] - 6s 99ms/step - loss: 9.0158e-04 - val_loss: 0.0078
# Epoch 60/100
# 63/63 [==============================] - 6s 100ms/step - loss: 0.0011 - val_loss: 0.0119
# Epoch 61/100
# 63/63 [==============================] - 6s 99ms/step - loss: 0.0012 - val_loss: 0.0661
# Epoch 62/100
# 63/63 [==============================] - 6s 100ms/step - loss: 0.0011 - val_loss: 1.8026e-04
# Epoch 63/100
# 63/63 [==============================] - 6s 99ms/step - loss: 0.0013 - val_loss: 3.1733e-04
# Epoch 64/100
# 63/63 [==============================] - 6s 100ms/step - loss: 0.0010 - val_loss: 0.0183
# Epoch 65/100
# 63/63 [==============================] - 6s 99ms/step - loss: 0.0011 - val_loss: 0.0028
# Epoch 66/100
# 63/63 [==============================] - 6s 98ms/step - loss: 0.0011 - val_loss: 0.0061
# Epoch 67/100
# 63/63 [==============================] - 6s 99ms/step - loss: 0.0011 - val_loss: 0.0066
# Epoch 68/100
# 63/63 [==============================] - 6s 99ms/step - loss: 0.0012 - val_loss: 0.0187
# Epoch 69/100
# 63/63 [==============================] - 6s 98ms/step - loss: 0.0013 - val_loss: 0.0126
# Epoch 70/100
# 63/63 [==============================] - 6s 99ms/step - loss: 0.0010 - val_loss: 7.5856e-04
# Epoch 71/100
# 63/63 [==============================] - 6s 98ms/step - loss: 0.
100
# 63/63 [==============================] - 6s 99ms/step - loss: 0.0010 - val_loss: 0.0054
# Epoch 97/100
# 63/63 [==============================] - 6s 100ms/step - loss: 9.3976e-04 - val_loss: 0.0067
# Epoch 98/100
# 63/63 [==============================] - 6s 100ms/step - loss: 0.0012 - val_loss: 0.0061
# Epoch 99/100
# 63/63 [==============================] - 6s 99ms/step - loss: 0.0010 - val_loss: 0.0051
# Epoch 100/100
# 63/63 [==============================] - 6s 99ms/step - loss: 8.4698e-04 - val_loss: 0.0069

# %%
# === Make Predictions ===
predicted_volatility = model.predict(X_test)
# Out:
# 16/16 [==============================] - 1s 24ms/step

# %%
# Reverse scale the predictions
predicted_volatility = scaler.inverse_transform(predicted_volatility.reshape(-1, 1))
y_test_actual = scaler.inverse_transform(y_test.reshape(-1, 1))

# %%
# === Create a new DataFrame for plotting results ===
# The test set covers the final len(y_test) points in df_lstm_pred
df_lstm_results = pd.DataFrame({
    "Date": df_lstm_pred.index[-len(y_test):],  # Match test set length
    "Predicted Volatility (LSTM)": predicted_volatility.flatten(),
    "Actual Volatility": y_test_actual.flatten()
})

# %%
# Set "Date" as the index
df_lstm_results.set_index("Date", inplace=True)

# %%
# === Plot Actual vs. Predicted Volatility ===
plt.figure(figsize=(12, 6))
plt.plot(df_lstm_results.index, df_lstm_results["Actual Volatility"], 
         label="Actual Volatility", color="red")
plt.plot(df_lstm_results.index, df_lstm_results["Predicted Volatility (LSTM)"], 
         label="Predicted Volatility (LSTM)", color="blue", linestyle="dashed")
plt.title("LSTM Forecast vs. Actual Volatility")
plt.legend()
plt.show()

# %%
# Save model
model.save("lstm_volatility_model.h5")
print("LSTM model saved!")
# Out:
# LSTM model saved!

# %%
# Save LSTM predictions
df_lstm_results = pd.DataFrame({
    "Date": df_lstm_pred.index[-len(y_test):],  # Match test set length
    "Predicted Volatility (LSTM)": predicted_volatility.flatten(),
    "Actual Volatility": y_test_actual.flatten()
})

df_lstm_results.set_index("Date", inplace=True)
df_lstm_results.to_csv("lstm_volatility_predictions.csv")

print("Improved LSTM predictions saved to 'improved_lstm_predictions.csv'")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 3
#       1 # Save LSTM predictions
#       2 df_lstm_pred = pd.DataFrame({
# ----> 3     "Date": df_garch_heston.index[-len(y_test):],  # Use the same index as test set
#       4     "Predicted Volatility (LSTM)": predicted_volatility.flatten()
#       5 })
#       6 df_lstm_pred.set_index("Date", inplace=True)
#       7 df_lstm_pred.to_csv("lstm_volatility_predictions.csv")
#
# NameError: name 'df_garch_heston' is not defined

# %%
# Load previous predictions (GARCH & Heston)
df_garch_heston = pd.read_csv("volatility_predictions.csv", index_col=0, parse_dates=True)

# Load LSTM predictions
df_lstm_pred = pd.read_csv("lstm_volatility_predictions.csv", index_col=0, parse_dates=True)

# Merge all data
df_compare = df_garch_heston.copy()
df_compare["LSTM_Volatility"] = df_lstm_pred["Predicted Volatility (LSTM)"]
