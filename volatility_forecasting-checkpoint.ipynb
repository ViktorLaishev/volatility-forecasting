# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from arch import arch_model
from scipy.optimize import minimize

# %%
file_path = "Price History_IVV_US_Equity.xlsx"
df = pd.read_excel(file_path, index_col=0, parse_dates=True)

# %%
print(df.head())
# Out:
#                 Close   Net      %Chg    Open       Low    High   Volume  \
# Exchange Date
# 2024-12-13     607.24 -0.11 -0.000181  609.44  605.8278  610.15  9729091
# 2024-12-12     607.35 -3.24 -0.005306  609.63  607.3500  610.17  5830787
# 2024-12-11     610.59  4.67  0.007707  608.80  608.5080  611.48  4892064
# 2024-12-10     605.92 -1.76 -0.002896  608.39  605.1600  608.72  4489053
# 2024-12-09     607.68 -3.15 -0.005157  610.75  607.0900  610.85  2973765
#
#                Turnover - USD
# Exchange Date
# 2024-12-13       5.909573e+09
# 2024-12-12       3.545192e+09
# 2024-12-11       2.986816e+09
# 2024-12-10       2.723671e+09
# 2024-12-09       1.809882e+09

# %%
# Ensure data is sorted by date
df = df.sort_index()

# Rescale log returns to avoid numerical issues
df['Scaled_Log_Returns'] = df['Log_Returns'] * 100  # Scale up to improve model convergence

# Plot historical volatility
plt.figure(figsize=(12, 6))
plt.plot(df.index, df['Rolling_Volatility'], label="30-day Rolling Volatility", color="red")
plt.title("Historical Rolling Volatility (Annualized)")
plt.legend()
plt.show()

# %%
# Histogram of log returns
plt.figure(figsize=(10,5))
sns.histplot(df['Log_Returns'], bins=50, kde=True, color="blue")
plt.title("Distribution of Log Returns")
plt.show()

# Scatter plot of returns vs. past volatility
plt.figure(figsize=(10,5))
plt.scatter(df['Rolling_Volatility'], df['Log_Returns'], alpha=0.5)
plt.title("Returns vs. Volatility")
plt.xlabel("Rolling Volatility")
plt.ylabel("Log Returns")
plt.show()

# %%
# === GARCH(1,1) Model ===
print("\nFitting GARCH(1,1) Model...")
garch_model = arch_model(df['Scaled_Log_Returns'].dropna(), vol='Garch', p=1, q=1)
garch_results = garch_model.fit()
print(garch_results.summary())
# Out:
# Fitting GARCH(1,1) Model...
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 29753.059557789722
# Iteration:      2,   Func. Count:     17,   Neg. LLF: 14883.992271388159
# Iteration:      3,   Func. Count:     27,   Neg. LLF: 5390.669932107616
# Iteration:      4,   Func. Count:     34,   Neg. LLF: 5728.4861564080975
# Iteration:      5,   Func. Count:     41,   Neg. LLF: 3328.8203301487633
# Iteration:      6,   Func. Count:     47,   Neg. LLF: 3312.360436311516
# Iteration:      7,   Func. Count:     52,   Neg. LLF: 3312.3604249566306
# Iteration:      8,   Func. Count:     57,   Neg. LLF: 3312.3604239950696
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3312.3604239950696
#             Iterations: 8
#             Function evaluations: 57
#             Gradient evaluations: 8
#                      Constant Mean - GARCH Model Results
# ==============================================================================
# Dep. Variable:     Scaled_Log_Returns   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                      GARCH   Log-Likelihood:               -3312.36
# Distribution:                  Normal   AIC:                           6632.72
# Method:            Maximum Likelihood   BIC:                           6656.16
#                                         No. Observations:                 2590
# Date:                Sat, Mar 15 2025   Df Residuals:                     2589
# Time:                        00:01:28   Df Model:                            1
#                                 Mean Model
# ==========================================================================
#                  coef    std err          t      P>|t|    95.0% Conf. Int.
# --------------------------------------------------------------------------
# mu             0.0808  1.446e-02      5.584  2.353e-08 [5.242e-02,  0.109]
#                               Volatility Model
# ============================================================================
#                  coef    std err          t      P>|t|      95.0% Conf. Int.
# ----------------------------------------------------------------------------
# omega          0.0388  9.451e-03      4.107  4.004e-05 [2.029e-02,5.734e-02]
# alpha[1]       0.1912  2.792e-02      6.849  7.442e-12     [  0.136,  0.246]
# beta[1]        0.7797  2.627e-02     29.685 1.216e-193     [  0.728,  0.831]
# ============================================================================
#
# Covariance estimator: robust

# %%
# Convert back to original scale
df['GARCH_Volatility'] = garch_results.conditional_volatility / 100 * np.sqrt(252)  # Annualized

# %%
# Plot GARCH vs. Rolling Volatility
plt.figure(figsize=(12, 6))
plt.plot(df.index, df['Rolling_Volatility'], label="Rolling Volatility", color="red")
plt.plot(df.index, df['GARCH_Volatility'], label="GARCH Volatility", color="blue", linestyle="dashed")
plt.title("GARCH vs. Rolling Volatility")
plt.legend()
plt.show()

# %%
def heston_loss(params, log_returns):
    """Loss function for calibrating Heston model parameters."""
    kappa, theta, sigma, rho, v0 = params
    
    dt = 1/252  # Daily time step
    n = len(log_returns)

    # Initialize arrays
    v_t = np.full(n, v0)
    s_t = np.exp(np.cumsum(log_returns))

    for t in range(1, n):  # Ensure correct loop range
        dz1, dz2 = np.random.normal(0, np.sqrt(dt), 2)
        dz2 = rho * dz1 + np.sqrt(1 - rho**2) * dz2
        v_t[t] = np.abs(v_t[t-1] + kappa * (theta - v_t[t-1]) * dt + sigma * np.sqrt(v_t[t-1]) * dz1)
        s_t[t] = s_t[t-1] * np.exp(-0.5 * v_t[t-1] * dt + np.sqrt(v_t[t-1] * dt) * dz2)

    # Ensure correct array length for loss function
    log_return_estimates = np.log(s_t[1:] / s_t[:-1])
    return np.mean((log_returns[1:] - log_return_estimates)**2)  # Use matching lengths

# %%
# Initial parameter guesses for Heston Model
initial_params = [2, 0.02, 0.1, -0.5, 0.02]
result = minimize(heston_loss, initial_params, args=(df['Log_Returns'].values,), method='Nelder-Mead')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [32], in <cell line: 3>()
#       1 # Initial parameter guesses for Heston Model
#       2 initial_params = [2, 0.02, 0.1, -0.5, 0.02]
# ----> 3 result = minimize(heston_loss, initial_params, args=(df['Log_Returns'].values,), method='Nelder-Mead')
#
# File c:\users\sigiz\appdata\local\programs\python\python39\lib\site-packages\scipy\optimize\_minimize.py:687, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     684     bounds = standardize_bounds(bounds, x0, meth)
#     686 if meth == 'nelder-mead':
# --> 687     res = _minimize_neldermead(fun, x0, args, callback, bounds=bounds,
#     688                                **options)
#     689 elif meth == 'powell':
#     690     res = _minimize_powell(fun, x0, args, callback, bounds, **options)
#
# File c:\users\sigiz\appdata\local\programs\python\python39\lib\site-packages\scipy\optimize\_optimize.py:772, in _minimize_neldermead(func, x0, args, callback, maxiter, maxfev, disp, return_all, initial_simplex, xatol, fatol, adaptive, bounds, **unknown_options)
#     770 try:
#     771     for k in range(N + 1):
# --> 772         fsim[k] = func(sim[k])
#     773 except _MaxFuncCallError:
#     774     pass
#
# File c:\users\sigiz\appdata\local\programs\python\python39\lib\site-packages\scipy\optimize\_optimize.py:496, in _wrap_scalar_function_maxfun_validation.<locals>.function_wrapper(x, *wrapper_args)
#     494 ncalls[0] += 1
#     495 # A copy of x is sent to the user function (gh13740)
# --> 496 fx = function(np.copy(x), *(wrapper_args + args))
#     497 # Ideally, we'd like to a have a true scalar returned from f(x). For
#     498 # backwards-compatibility, also allow np.array([1.3]),
#     499 # np.array([[1.3]]) etc.
#     500 if not np.isscalar(fx):
#
# Input In [31], in heston_loss(params, log_returns)
#      13     v_t[t] = np.abs(v_t[t-1] + kappa * (theta - v_t[t-1]) * dt + sigma * np.sqrt(v_t[t-1]) * dz1)
#      14     s_t[t] = s_t[t-1] * np.exp(-0.5 * v_t[t-1] * dt + np.sqrt(v_t[t-1] * dt) * dz2)
# ---> 16 return np.mean((log_returns - np.log(s_t[:-1] / s_t[1:]))**2)
#
# ValueError: operands could not be broadcast together with shapes (2590,) (2589,)

# %%
# Compute Heston-implied volatility
df['Heston_Volatility'] = np.sqrt(v0_opt) * np.sqrt(252)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [24], in <cell line: 2>()
#       1 # Compute Heston-implied volatility
# ----> 2 df['Heston_Volatility'] = np.sqrt(v0_opt) * np.sqrt(252)
#
# NameError: name 'v0_opt' is not defined

# %%
# Plot Heston vs. GARCH vs. Rolling Volatility
plt.figure(figsize=(12, 6))
plt.plot(df.index, df['Rolling_Volatility'], label="Rolling Volatility", color="red")
plt.plot(df.index, df['GARCH_Volatility'], label="GARCH Volatility", color="blue", linestyle="dashed")
plt.plot(df.index, df['Heston_Volatility'], label="Heston Volatility", color="green", linestyle="dotted")
plt.title("Heston vs. GARCH vs. Rolling Volatility")
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\users\sigiz\appdata\local\programs\python\python39\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File c:\users\sigiz\appdata\local\programs\python\python39\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\users\sigiz\appdata\local\programs\python\python39\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Heston_Volatility'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [25], in <cell line: 5>()
#       3 plt.plot(df.index, df['Rolling_Volatility'], label="Rolling Volatility", color="red")
#       4 plt.plot(df.index, df['GARCH_Volatility'], label="GARCH Volatility", color="blue", linestyle="dashed")
# ----> 5 plt.plot(df.index, df['Heston_Volatility'], label="Heston Volatility", color="green", linestyle="dotted")
#       6 plt.title("Heston vs. GARCH vs. Rolling Volatility")
#       7 plt.legend()
#
# File c:\users\sigiz\appdata\local\programs\python\python39\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File c:\users\sigiz\appdata\local\programs\python\python39\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'Heston_Volatility'

# %%
# Extract GARCH volatility predictions
df['GARCH_Volatility'] = garch_results.conditional_volatility * np.sqrt(252)  # Annualized

# Plot GARCH vs. Rolling Volatility
plt.figure(figsize=(12, 6))
plt.plot(df.index, df['Rolling_Volatility'], label="30-day Rolling Volatility", color="red")
plt.plot(df.index, df['GARCH_Volatility'], label="GARCH Volatility", color="blue", linestyle="dashed")
plt.title("GARCH(1,1) Volatility vs. Rolling Volatility")
plt.legend()
plt.show()

# %%
df.to_csv("processed_IVV_data.csv")
print("Processed data saved!")
# Out:
# Processed data saved!
